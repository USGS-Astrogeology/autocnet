# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

from autocnet.examples import get_path
from autocnet.graph.network import CandidateGraph
from autocnet.graph.edge import Edge
# from autocnet.matcher.feature import FlannMatcher

from IPython.display import display

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Generate a 2 image adjacenecy graph

# %%
#Point to the adjacency Graph
adjacency = get_path('three_image_adjacency.json')
basepath = get_path('Apollo15')
cg = CandidateGraph.from_adjacency(adjacency, basepath=basepath)

#Apply SIFT to extract features
cg.extract_features(extractor_parameters={'nfeatures':500})

# %%
# %%time
#Match
cg.match()

# #Apply outlier detection
cg.apply_func_to_edges(Edge.symmetry_check)
cg.apply_func_to_edges(Edge.ratio_check)
cg.minimum_spanning_tree()

#Compute a homography and apply RANSAC
cg.apply_func_to_edges("compute_fundamental_matrix", clean_keys=['ratio', 'symmetry'])
# Out:
# CPU times: user 1min 4s, sys: 111 ms, total: 1min 4s
# Wall time: 1min 4s

# %%
# %%time 
cg.generate_control_network().head()
# Out:
# CPU times: user 11.2 s, sys: 13.4 ms, total: 11.2 s
# Wall time: 11.2 s
#             point_id  image_index  keypoint_index        edge  match_idx  \
# measure_id
# 0                  0            0             488  (0.0, 2.0)          0
# 1                  0            2               0  (0.0, 2.0)          0
# 2                  0            0             321  (0.0, 2.0)          1
# 3                  1            0             142  (0.0, 2.0)          2
# 4                  1            2               1  (0.0, 2.0)          2
#
#                      x           y  x_off  y_off  corr
# measure_id
# 0           551.074341  580.615234      0      0   inf
# 1           967.196411   35.992252      0      0   inf
# 2           806.324524  985.594177      0      0   inf
# 3            92.411133  285.567230      0      0   inf
# 4           232.147171   36.320156      0      0   inf

# %%
cg.masks.head()
# Out:
#      edge  match_idx  symmetry  ratio fundamental
# 0  (0, 1)          0      True  False       False
# 1  (0, 1)          1      True  False       False
# 2  (0, 1)          2      True   True        True
# 3  (0, 1)          3     False  False       False
# 4  (0, 1)          4      True   True        True

# %% [markdown]
# ### The graph object:
# The underlying data structure is a graph, where each node is an image and each edge is the connectivity between nodes.  Nodes and Edges are classes with associated attributes and methods.  This notebook primarily focuses on the plotting functionality on the graph (and graph components).
#
# In these notebooks, the graph object is being stored in the variable `cg`.  Access to nodes and edges is positional.
#
#   * To access a node in the graph:  `cg[node_idx]`, e.g. `cg[0]`.
#   * To access an edge in the graph: `cg[source_idx][destination_idx]`, e.g. `cg[0][1]`

# %% [markdown]
# ## Plot the graph

# %%
cg.plot()

# %% [markdown]
# ## Plot features at an individual node, e.g. a single image

# %% [markdown]
# All defaults are used here.

# %%
cg.node[1]['data'].plot()

# %% [markdown]
# This example specifies a plotting layout, passing in an axis object and passes along a color.  All the MatPlotLib plotting arguments are supported.

# %%
ax1 = plt.subplot(1,1,1)
ax = cg.node[0]['data'].plot(ax=ax1, color='y')

# %% [markdown]
# ## Plotting Matches on an Edge
# The plotting capability on a given node is limited to a single image; one can envision the node as being the image with all associated metadata and derived information.  The edge represents the overlap between images and resultant shared information, e.g. point correspondences, a homography, etc.

# %% [markdown]
# #### Plot the matches between an edge using two outlier detector masks
# To get a rough idea of what a 'good' results should be, we should see no, or few, lines which intersect.

# %%
fig, ax = plt.subplots(1,1)
print(ax)
ax = cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental'], ax=ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
fig, ax = plt.subplots(1,1)
cg[0][1]['data'].plot_source(clean_keys=['ratio', 'symmetry', 'fundamental'], ax=ax)

# %%
fig, ax = plt.subplots(1,1)
cg[1][2]['data'].plot(node='d', clean_keys=['ratio', 'symmetry', 'fundamental'])

# %% [markdown]
# #### Now plot with the added, ransac computed mask

# %%
cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental'], line_kwargs={'linewidth':0})

# %% [markdown]
# ## Subpixel Register
# We suggest only subpixel registering 'good' candidate matches as the subpixel registration process can be time consuming.

# %%
cg[0][1]['data'].subpixel_register(clean_keys=['fundamental', 'symmetry', 'ratio'],template_size=5, search_size=15)
# Out:
# []

# %%
cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental', 'subpixel'])

# %%
cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental', 'subpixel'], line_kwargs={'linewidth':0})

# %% [markdown]
# ## Apply Suppression vis Disk Covering
# This method seeks to keep the $k$ strongest correlations with a good spatial distribution.

# %%
from autocnet.matcher import suppression_funcs as spf
cg[0][1]['data'].suppress(k=100)

# Plot, in blue the points that passed all outlier detectors so far
cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental', 'subpixel'], line_kwargs={'linewidth':0})
# Overlay, in red, the points that remain after suppression
cg[0][1]['data'].plot(clean_keys=['suppression'], line_kwargs={'linewidth':0}, scatter_kwargs={'color':'red'})
# Out:
# Index(['source_image', 'source_idx', 'destination_image', 'destination_idx',
#        'distance', 'x', 'y'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063             try:
# -> 3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-c96f9783cb4a> in <module>()
#       1 from autocnet.matcher import suppression_funcs as spf
# ----> 2 cg[0][1]['data'].suppress(k=100)
#       3
#       4 # Plot, in blue the points that passed all outlier detectors so far
#       5 cg[0][1]['data'].plot(clean_keys=['ratio', 'symmetry', 'fundamental', 'subpixel'], line_kwargs={'linewidth':0})
#
# ~/repos/autocnet/autocnet/graph/edge.py in suppress(self, suppression_func, clean_keys, maskname, **kwargs)
#     404         merged['strength'] = merged.apply(suppression_func, axis=1, args=([self]))
#     405
# --> 406         smask, k = od.spatial_suppression(merged, domain, **kwargs)
#     407
#     408         mask[mask] = smask
#
# ~/repos/autocnet/autocnet/matcher/cpu_outlier_detector.py in spatial_suppression(df, bounds, xkey, ykey, k, error_k, nsteps)
#     133         x_edges = np.linspace(minx, maxx, n_x_cells)
#     134         y_edges = np.linspace(miny, maxy, n_y_cells)
# --> 135         xbins = np.digitize(df[xkey], bins=x_edges)
#     136         ybins = np.digitize(df[ykey], bins=y_edges)
#     137
#
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/autocnet/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
# -> 3066                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3067
#    3068         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lon'

# %%
dir(cg[0][1])
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
import pandas as pd
cg.apply_func_to_edges(Edge.symmetry_check)
cg.apply_func_to_edges(Edge.ratio_check)
masks = pd.DataFrame()
print(masks)
mask_list = cg.apply(lambda x:(x.source, x.destination, x.masks))
for s,d, mask in mask_list:
    mask = mask.reset_index().rename(columns={'index':'match_idx'})
    # drop edge, destination columns since they are uneeded 
    mask = mask.drop(['source', 'destination'], axis=1)
    mask['edge'] = [(s['node_id'], d['node_id'])]*mask.shape[0]
    masks = masks.append(mask)
masks = masks.reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
masks.head()
# Out:
#    match_idx  symmetry  ratio    edge
# 0          0      True  False  (0, 1)
# 1          1      True  False  (0, 1)
# 2          2      True   True  (0, 1)
# 3          3     False  False  (0, 1)
# 4          4      True   True  (0, 1)

# %%
cg.controlnetwork.head()
# Out:
#             point_id  image_index  keypoint_index        edge  match_idx  \
# measure_id
# 0                  0            0             322  (0.0, 1.0)          0
# 1                  0            1               0  (0.0, 1.0)          0
# 2                  0            0             465  (0.0, 1.0)          1
# 3                  1            0               1  (0.0, 1.0)          2
# 4                  1            1               1  (0.0, 1.0)          2
#
#                      x           y x_off y_off  corr valid
# measure_id
# 0            53.983700  112.867981     0     0   inf  True
# 1           273.929138  107.707611     0     0   inf  True
# 2           852.296631  221.722504     0     0   inf  True
# 3           193.436554  553.746155     0     0   inf  True
# 4           413.602264  553.731812     0     0   inf  True

# %%
masks['all'] = masks[['symmetry', 'ratio']].all(axis=1)
p = cg.controlnetwork.merge(masks, on=['edge', 'match_idx'])
p[p['all'] == True]
# Out:
#       point_id  image_index  keypoint_index        edge  match_idx  \
# 3            1            0               1  (0.0, 1.0)          2
# 4            1            1               1  (0.0, 1.0)          2
# 6            2            0             282  (0.0, 1.0)          4
# 7            2            1               2  (0.0, 1.0)          4
# 9            3            0              53  (0.0, 1.0)          6
# 10           3            1               3  (0.0, 1.0)          6
# 12           4            0             452  (0.0, 1.0)          8
# 13           4            1               4  (0.0, 1.0)          8
# 21           7            0             268  (0.0, 1.0)         14
# 22           7            1               7  (0.0, 1.0)         14
# 29          10            0              37  (0.0, 1.0)         20
# 30          10            1              10  (0.0, 1.0)         20
# 34          12            0             361  (0.0, 1.0)         24
# 35          12            1              12  (0.0, 1.0)         24
# 40          14            0             360  (0.0, 1.0)         28
# 41          14            1              14  (0.0, 1.0)         28
# 43          15            0              27  (0.0, 1.0)         30
# 44          15            1              15  (0.0, 1.0)         30
# 60          20            0             183  (0.0, 1.0)         42
# 61          20            1              21  (0.0, 1.0)         42
# 63          21            0             154  (0.0, 1.0)         44
# 64          21            1              22  (0.0, 1.0)         44
# 68          22            0             216  (0.0, 1.0)         48
# 69          22            1              24  (0.0, 1.0)         48
# 71          23            0             188  (0.0, 1.0)         50
# 72          23            1              25  (0.0, 1.0)         50
# 74          24            0             162  (0.0, 1.0)         52
# 75          24            1              26  (0.0, 1.0)         52
# 77          25            0             157  (0.0, 1.0)         54
# 78          25            1              27  (0.0, 1.0)         54
# ...        ...          ...             ...         ...        ...
# 1132       115            2             132  (1.0, 2.0)        264
# 1139       165            2             139  (1.0, 2.0)        278
# 1145       103            2             145  (1.0, 2.0)        290
# 1147       134            2             147  (1.0, 2.0)        294
# 1152       191            2             152  (1.0, 2.0)        304
# 1160       200            2             160  (1.0, 2.0)        320
# 1162       188            2             162  (1.0, 2.0)        324
# 1168       163            2             168  (1.0, 2.0)        336
# 1180        87            2             180  (1.0, 2.0)        360
# 1181        93            2             181  (1.0, 2.0)        362
# 1191        99            2             191  (1.0, 2.0)        382
# 1195       153            2             195  (1.0, 2.0)        390
# 1198       184            2             198  (1.0, 2.0)        396
# 1208        38            2             208  (1.0, 2.0)        416
# 1210        46            2             210  (1.0, 2.0)        420
# 1218       144            2             218  (1.0, 2.0)        436
# 1237       225            2             237  (1.0, 2.0)        474
# 1247       234            2             247  (1.0, 2.0)        494
# 1263        76            2             263  (1.0, 2.0)        526
# 1264       236            2             264  (1.0, 2.0)        528
# 1266       122            2             266  (1.0, 2.0)        532
# 1276        51            2             276  (1.0, 2.0)        552
# 1278       184            2             278  (1.0, 2.0)        556
# 1282       176            2             282  (1.0, 2.0)        564
# 1296        61            2             296  (1.0, 2.0)        592
# 1300       119            2             300  (1.0, 2.0)        600
# 1318       219            2             318  (1.0, 2.0)        636
# 1323        16            2             323  (1.0, 2.0)        646
# 1358       117            2             358  (1.0, 2.0)        716
# 1372        31            2             372  (1.0, 2.0)        744
#
#                x           y x_off y_off  corr valid  symmetry  ratio   all
# 3     193.436554  553.746155     0     0   inf  True      True   True  True
# 4     413.602264  553.731812     0     0   inf  True      True   True  True
# 6     388.803284  708.786865     0     0   inf  True      True   True  True
# 7     610.340454  708.182068     0     0   inf  True      True   True  True
# 9     724.273193  819.445984     0     0   inf  True      True   True  True
# 10    941.973450  815.207825     0     0   inf  True      True   True  True
# 12    561.140686   64.150116     0     0   inf  True      True   True  True
# 13    781.526489   66.304314     0     0   inf  True      True   True  True
# 21    381.803314  250.404572     0     0   inf  True      True   True  True
# 22    607.215454  248.005417     0     0   inf  True      True   True  True
# 29    720.421631  769.308655     0     0   inf  True      True   True  True
# 30    941.452698  765.773682     0     0   inf  True      True   True  True
# 34     33.673618  743.318115     0     0   inf  True      True   True  True
# 35    244.372040  746.032349     0     0   inf  True      True   True  True
# 40     33.673618  743.318115     0     0   inf  True      True   True  True
# 41    244.372040  746.032349     0     0   inf  True      True   True  True
# 43    221.989166  547.352234     0     0   inf  True      True   True  True
# 44    443.406128  546.975342     0     0   inf  True      True   True  True
# 60    650.125732  459.072540     0     0   inf  True      True   True  True
# 61    868.847656  459.278534     0     0   inf  True      True   True  True
# 63    657.087646   15.598196     0     0   inf  True      True   True  True
# 64    868.939453   20.219540     0     0   inf  True      True   True  True
# 68    639.119019  998.439270     0     0   inf  True      True   True  True
# 69    850.125916  993.001404     0     0   inf  True      True   True  True
# 71    649.224915  499.879272     0     0   inf  True      True   True  True
# 72    869.388550  499.787750     0     0   inf  True      True   True  True
# 74    653.998596  252.633057     0     0   inf  True      True   True  True
# 75    869.466370  254.836426     0     0   inf  True      True   True  True
# 77    653.998596  252.633057     0     0   inf  True      True   True  True
# 78    869.466370  254.836426     0     0   inf  True      True   True  True
# ...          ...         ...   ...   ...   ...   ...       ...    ...   ...
# 1132  454.789734  216.252365     0     0   inf  True      True   True  True
# 1139  474.081299  984.800110     0     0   inf  True      True   True  True
# 1145  480.101135  534.080750     0     0   inf  True      True   True  True
# 1147  482.260590  973.019104     0     0   inf  True      True   True  True
# 1152  985.959290  384.589508     0     0   inf  True      True   True  True
# 1160  765.390930  881.571106     0     0   inf  True      True   True  True
# 1162  494.396881  843.236755     0     0   inf  True      True   True  True
# 1168  501.139130  904.060547     0     0   inf  True      True   True  True
# 1180  756.075317  494.616150     0     0   inf  True      True   True  True
# 1181  756.075317  494.616150     0     0   inf  True      True   True  True
# 1191  539.207825  984.441040     0     0   inf  True      True   True  True
# 1195  547.053528  139.010544     0     0   inf  True      True   True  True
# 1198  562.781433  689.921814     0     0   inf  True      True   True  True
# 1208  747.568237  960.530701     0     0   inf  True      True   True  True
# 1210  579.320618  540.029724     0     0   inf  True      True   True  True
# 1218  591.132202  251.618393     0     0   inf  True      True   True  True
# 1237  612.213074  790.008789     0     0   inf  True      True   True  True
# 1247  637.021667  663.173462     0     0   inf  True      True   True  True
# 1263  684.679016  139.514862     0     0   inf  True      True   True  True
# 1264  731.118530   70.817017     0     0   inf  True      True   True  True
# 1266  998.912659  139.999832     0     0   inf  True      True   True  True
# 1276  729.425903  756.156433     0     0   inf  True      True   True  True
# 1278  716.257324  804.276367     0     0   inf  True      True   True  True
# 1282  719.394897  525.216125     0     0   inf  True      True   True  True
# 1296  476.245239  994.667236     0     0   inf  True      True   True  True
# 1300  453.261749  376.792603     0     0   inf  True      True   True  True
# 1318  940.964417  174.078812     0     0   inf  True      True   True  True
# 1323  823.557129  122.196953     0     0   inf  True      True   True  True
# 1358  767.231384  138.792511     0     0   inf  True      True   True  True
# 1372  546.403931  977.597900     0     0   inf  True      True   True  True
#
# [226 rows x 14 columns]

# %%
set(cg[0][1]['data'].masks.columns) - {'source', 'destination'}
# Out:
# {'ratio', 'symmetry'}

# %%
mask2 = mask.drop(['test'], axis=1)

# %%
mask['test'] = [True]*mask.shape[0]

# %%
mask2.head()
# Out:
#    match_idx  symmetry  ratio    edge
# 0          0      True  False  (0, 2)
# 1          1      True  False  (0, 2)
# 2          2      True  False  (0, 2)
# 3          3      True  False  (0, 2)
# 4          4      True  False  (0, 2)

# %%
update_masks(cg).head()
# Out:
#    match_idx  symmetry  ratio    edge
# 0          0      True  False  (0, 1)
# 1          1      True  False  (0, 1)
# 2          2      True   True  (0, 1)
# 3          3     False  False  (0, 1)
# 4          4      True   True  (0, 1)

# %%
cg.masks.head()
# Out:
#    match_idx  symmetry  ratio    edge  newmask
# 0          0      True  False  (0, 1)     True
# 1          1      True  False  (0, 1)     True
# 2          2      True   True  (0, 1)     True
# 3          3     False  False  (0, 1)     True
# 4          4      True   True  (0, 1)     True

# %%
def f(l):
    l.append(1)
f(lis)
lis
# Out:
# [1, 1, 1]
